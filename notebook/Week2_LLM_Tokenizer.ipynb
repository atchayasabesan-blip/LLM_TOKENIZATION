# %%
import pandas as pd
from transformers import BertTokenizer, GPT2Tokenizer

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
import pandas as pd

df = pd.read_csv("../dataset/clean_text.csv")

df
# Out:
#                                           Clean_Text
# 0  the statute drew legal influence from previous...

# %%
print(df["text"].tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df["clean_text"].head(5).tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df["clean_text"].tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Clean_Text']

# %%
print(df["clean_Text"].head(5).tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df["Clean_Text"].head(5).tolist())
# Out:
# ['the statute drew legal influence from previous measures including those undertaken by the holy roman empire and prussian states it was amended several times the nazis broadened the law in as part of the most severe persecution of homosexual men in history it was one of the few naziera laws to be retained in their original form in west germany although east germany reverted to the prenazi version']

# %%
bert_tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

text = df["text"].iloc[0]

tokens = bert_tokenizer.tokenize(text)

print("Original text:", text)
print("BERT tokens:", tokens)
# Out:
# ...
# c:\Users\S ATCHAYA SABESAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\S ATCHAYA SABESAN\.cache\huggingface\hub\models--bert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
bert_tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

text = df["Clean_Text"].iloc[0]

tokens = bert_tokenizer.tokenize(Clean_Text)

print("Original text:", Clean_Text)
print("BERT tokens:", tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 bert_tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
#       2
#       3 text = df["Clean_Text"].iloc[0]
#       4
# ----> 5 tokens = bert_tokenizer.tokenize(Clean_Text)
#       6
#       7 print("Original text:", Clean_Text)
#       8 print("BERT tokens:", tokens)
#
# NameError: name 'Clean_Text' is not defined

# %%
bert_tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

text = df["Clean_Text"].iloc[0]

tokens = bert_tokenizer.tokenize(text)

print("Original text:", text)
print("BERT tokens:", tokens)
# Out:
# Original text: the statute drew legal influence from previous measures including those undertaken by the holy roman empire and prussian states it was amended several times the nazis broadened the law in as part of the most severe persecution of homosexual men in history it was one of the few naziera laws to be retained in their original form in west germany although east germany reverted to the prenazi version
# ...

# %%
gpt2_tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

gpt2_tokens = gpt2_tokenizer.tokenize(text)

print("Original text:", text)
print("GPT-2 tokens:", gpt2_tokens)
# Out:
# c:\Users\S ATCHAYA SABESAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\S ATCHAYA SABESAN\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
bert_ids = bert_tokenizer.encode(text)
gpt2_ids = gpt2_tokenizer.encode(text)

print("BERT Token IDs:")
print(bert_ids)

print("\nGPT-2 Token IDs:")
print(gpt2_ids)
# Out:
# BERT Token IDs:
# [101, 1996, 11671, 3881, 3423, 3747, 2013, 3025, 5761, 2164, 2216, 10607, 2011, 1996, 4151, 3142, 3400, 1998, 10734, 2163, 2009, 2001, 13266, 2195, 2335, 1996, 13157, 5041, 6675, 1996, 2375, 1999, 2004, 2112, 1997, 1996, 2087, 5729, 14522, 1997, 15667, 2273, 1999, 2381, 2009, 2001, 2028, 1997, 1996, 2261, 6394, 6906, 4277, 2000, 2022, 6025, 1999, 2037, 2434, 2433, 1999, 2225, 2762, 2348, 2264, 2762, 16407, 2000, 1996, 3653, 2532, 5831, 2544, 102]
#
# GPT-2 Token IDs:
# [1169, 14195, 9859, 2742, 4588, 422, 2180, 5260, 1390, 883, 21846, 416, 262, 11386, 374, 5185, 13735, 290, 778, 31562, 2585, 340, 373, 11412, 1811, 1661, 262, 299, 1031, 271, 3154, 2945, 262, 1099, 287, 355, 636, 286, 262, 749, 6049, 22839, 286, 11479, 1450, 287, 2106, 340, 373, 530, 286, 262, 1178, 299, 1031, 41976, 3657, 284, 307, 17383, 287, 511, 2656, 1296, 287, 7421, 308, 2224, 88, 3584, 7627, 308, 2224, 88, 50239, 284, 262, 662, 77, 7761, 2196]

# %%
comparison = pd.DataFrame({
    "Text": [text],
    "BERT Tokens": [bert_tokenizer.tokenize(text)],
    "GPT-2 Tokens": [gpt2_tokenizer.tokenize(text)],
    "BERT Token Count": [len(bert_ids)],
    "GPT-2 Token Count": [len(gpt2_ids)]
})

comparison
# Out:
#                                                 Text  \
# 0  the statute drew legal influence from previous...
#
#                                          BERT Tokens  \
# 0  [the, statute, drew, legal, influence, from, p...
#
#                                         GPT-2 Tokens  BERT Token Count  \
# 0  [the, Ġstatute, Ġdrew, Ġlegal, Ġinfluence, Ġfr...                74
#
#    GPT-2 Token Count
# 0                 81

# %%
comparison.to_csv("../dataset/tokenization_comparison.csv", index=False)

print("Comparison saved successfully!")
# Out:
# Comparison saved successfully!

# %%
token_ids = pd.DataFrame({
    "Text": [text],
    "BERT Token IDs": [bert_ids],
    "GPT-2 Token IDs": [gpt2_ids]
})

token_ids.to_csv("../dataset/token_ids.csv", index=False)

print("Token IDs saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[16], line 7
#       3     "BERT Token IDs": [bert_ids],
#       4     "GPT-2 Token IDs": [gpt2_ids]
#       5 })
#       6
# ----> 7 token_ids.to_csv("../dataset/token_ids.csv", index=False)
#       8
#       9 print("Token IDs saved successfully!")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
token_ids = pd.DataFrame({
    "Text": [text],
    "BERT Token IDs": [bert_ids],
    "GPT-2 Token IDs": [gpt2_ids]
})

token_ids.to_csv("../dataset/token_ids.csv", index=False)

print("Token IDs saved successfully!")
# Out:
# Token IDs saved successfully!

# %%
vocab = bert_tokenizer.get_vocab()

with open("../dataset/vocabulary.txt", "w", encoding="utf-8") as f:
    for token, token_id in sorted(vocab.items(), key=lambda x: x[1]):
        f.write(f"{token}\t{token_id}\n")

print("Vocabulary saved successfully!")
# Out:
# Vocabulary saved successfully!

# %%
import os

print(os.listdir("../dataset"))
# Out:
# ['clean_text.csv', 'comparison.csv', 'tokenization_comparison.csv', 'token_ids.csv', 'vocabulary.txt']

# %%
import os

files = os.listdir("../dataset")

print("FINAL DATASET FILES:")
for file in files:
    print("✓", file)
# Out:
# FINAL DATASET FILES:
# ✓ clean_text.csv
# ✓ tokenization_comparison.csv
# ✓ token_ids.csv
# ✓ vocabulary.txt

# %%
import pandas as pd

df = pd.read_csv("../dataset/tokenization_comparison.csv")

print("Dataset shape:", df.shape)
display(df)
# Out:
# Dataset shape: (1, 5)
#                                                 Text  \
# 0  the statute drew legal influence from previous...
#
#                                          BERT Tokens  \
# 0  ['the', 'statute', 'drew', 'legal', 'influence...
#
#                                         GPT-2 Tokens  BERT Token Count  \
# 0  ['the', 'Ġstatute', 'Ġdrew', 'Ġlegal', 'Ġinflu...                74
#
#    GPT-2 Token Count
# 0                 81

# %%
print("Tokenization Comparison")
print("------------------------")

bert_count = df["BERT Token Count"].iloc[0]
gpt2_count = df["GPT-2 Token Count"].iloc[0]

print("BERT Token Count :", bert_count)
print("GPT-2 Token Count:", gpt2_count)

if bert_count > gpt2_count:
    print("BERT uses more tokens than GPT-2.")
elif gpt2_count > bert_count:
    print("GPT-2 uses more tokens than BERT.")
else:
    print("Both use the same number of tokens.")
# Out:
# Tokenization Comparison
# ------------------------
# BERT Token Count : 74
# GPT-2 Token Count: 81
# GPT-2 uses more tokens than BERT.

# %%
print("Final Tokenization Summary")
print("==========================")

print("Input Text:")
print(df["Text"].iloc[0])

print("\nBERT Token Count:", df["BERT Token Count"].iloc[0])
print("GPT-2 Token Count:", df["GPT-2 Token Count"].iloc[0])

print("\nConclusion:")
print("BERT uses more tokens than GPT-2 for this text.")
# Out:
# Final Tokenization Summary
# ...
# Input Text:
# the statute drew legal influence from previous measures including those undertaken by the holy roman empire and prussian states it was amended several times the nazis broadened the law in as part of the most severe persecution of homosexual men in history it was one of the few naziera laws to be retained in their original form in west germany although east germany reverted to the prenazi version
#
# BERT Token Count: 74
# GPT-2 Token Count: 81
#
# Conclusion:
# BERT uses more tokens than GPT-2 for this text.

# %%
print("Project Completed Successfully!")
print("BERT Token Count:", bert_count)
print("GPT-2 Token Count:", gpt2_count)
print("BERT uses more tokens than GPT-2.")
# Out:
# Project Completed Successfully!
# BERT Token Count: 74
# GPT-2 Token Count: 81
# BERT uses more tokens than GPT-2.
